# %% [markdown]
# <a href="https://colab.research.google.com/github/pedraov/TrabalhoPHP/blob/main/LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Foram feitas as seguintes perguntas para cada LLM testada:
# Perguntas teste:
#
# (Todas as perguntas a seguir foram testadas em suas configurações padrão)
#
# 1- Escreva uma consulta SQL para encontrar todos os subordinados diretos e indiretos de um funcionário específico na tabela 'funcionarios' com colunas 'id', 'nome' e 'supervisor_id'.
#
#
#
# 2- Escreva uma consulta SQL para transformar a tabela 'vendas' com colunas 'data', 'categoria' e 'valor' em uma tabela pivoteada que mostre o valor total de vendas por categoria em cada mês.
#
#
#
# 3- Escreva uma consulta SQL para encontrar os produtos cujo preço é maior que a média dos preços dos produtos da mesma categoria na tabela 'produtos'.

# %% [markdown]
# Gemma:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sabiá
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Snowflake Artic:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Vanna:
#
# ![image.png](data:image/png;base64,...)
#
# Importação:
#
# ![image.png](data:image/png;base64,...)
#
# Como treina?
#
# ![image.png](data:image/png;base64,...)
#
# Fazendo perguntas:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# GPT 4:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Gemini:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
